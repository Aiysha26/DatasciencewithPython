# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df_auto_dataset=pd.read_csv('C:/Users/Aiysha/Desktop/DATA SCIENCE/Visual & time series/auto_data.csv')

# %%
df_auto_dataset.head(30)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 1   15.0          8         350.0        165    3693          11.5
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# ...

# %%
def origin(num):
    if num == 1:
        return 'USA'
    elif num == 2:
        return 'Europe'
    else:
        return 'asia'

# %%
df_auto_dataset[origin] = df_auto_dataset[origin].apply(origin)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-fbc2732c2597> in <module>
# ----> 1 df_auto_dataset[origin] = df_auto_dataset[origin].apply(origin)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2767     def __getitem__(self, key):
#    2768         key = lib.item_from_zerodim(key)
# -> 2769         key = com.apply_if_callable(key, self)
#    2770
#    2771         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     341
#     342     if callable(maybe_callable):
# --> 343         return maybe_callable(obj, **kwargs)
#     344
#     345     return maybe_callable
#
# <ipython-input-15-62df64d5a1a7> in origin(num)
#       1 def origin(num):
# ----> 2     if num == 1:
#       3         return 'USA'
#       4     elif num == 2:
# ...

# %%
sns.pairplot(df_auto_dataset[['mpg','weight','origin']],hue='origin',size=6)
# Out:
# C:\Users\Aiysha\anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
