# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from matplotlib import image

# %%
img=image.imread('farhaan.jpg')

# %%
img
# Out:
# array([[[254, 191,  75],
#         [254, 191,  75],
#         [254, 191,  75],
#         ...,
#         [239, 145,  55],
#         [239, 145,  55],
#         [239, 145,  55]],
#
#        [[254, 191,  75],
#         [254, 191,  75],
#         [254, 191,  75],
#         ...,
#         [239, 145,  55],
#         [239, 145,  55],
#         [239, 145,  55]],
#
#        [[255, 190,  74],
#         [255, 190,  74],
#         [255, 190,  74],
#         ...,
#         [238, 144,  54],
#         [238, 144,  54],
#         [238, 144,  54]],
#
#        ...,
#
#        [[189, 142,  96],
#         [190, 142,  96],
#         [190, 142,  94],
#         ...,
#         [178, 135,  90],
#         [177, 134,  91],
#         [177, 134,  91]],
#
#        [[188, 141,  95],
#         [188, 141,  95],
#         [190, 142,  96],
#         ...,
#         [176, 133,  88],
#         [176, 133,  88],
#         [175, 132,  89]],
#
#        [[188, 141,  97],
#         [188, 141,  95],
#         [188, 141,  95],
# ...

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)

# %%
img.max()
# Out:
# 255

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)

# %%
row= 50:100
col= 125 : 200
# Out:
#   File "<ipython-input-23-1da3983e1946>", line 1
#     row= 50:100
#            ^
# SyntaxError: invalid syntax

# %%
row= 15 : 140
col= 125 : 200  
im=img[15:140,125:200]
# Out:
#   File "<ipython-input-25-bd0fc1d7ff72>", line 1
#     row= 15 : 140
#             ^
# SyntaxError: invalid syntax

# %%
im
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-e371e598fe9f> in <module>
# ----> 1 im
#
# NameError: name 'im' is not defined

# %%
im=img[15:140,125:200]

# %%
plt.imshow(im)
